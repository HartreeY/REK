# %% [markdown]
# ### 1d.ipynb
# #### This is a notebook containing an example of a 1D axial range expansion.
# ---
# First, include the RESK library:

# %%
include("../resk.jl")
# Out:
# RESK successfully loaded.

# %% [markdown]
# For a simpler calculation, it is sometimes viable to simulate a range expansion using the infinite sites model. Simply use the suffix *_inf* for infinite-sites simulations:

# %%
test = rangeexp_1d(30,100;data_to_generate="FPSN")
# Out:
# Dict{String, Any} with 9 entries:
#   "AAsel" => Float32[0.0 0.0 … 20.7391 19.2917; 0.0 0.0 … 14.1905 16.3462; … ; …
#   "pops"  => Float32[11.0 15.0 … 24.0 16.0; 20.0 17.0 … 22.0 16.0; … ; NaN NaN …
#   "aasel" => Float32[500.0 499.615 … 470.174 468.042; 500.0 499.875 … 466.905 4…
#   "fitn"  => Float32[1.0 1.0 … 0.959358 0.962182; 1.0 1.0 … 0.972058 0.967877; …
#   "aaneu" => Float32[500.0 499.538 … 476.565 476.292; 500.0 499.625 … 474.476 4…
#   "Aasel" => Float32[0.0 0.384615 … 9.08696 12.6667; 0.0 0.125 … 18.9048 15.0; …
#   "Aaneu" => Float32[0.0 0.461538 … 10.1304 11.4167; 0.0 0.375 … 15.8571 15.307…
#   "AAneu" => Float32[0.0 0.0 … 13.3043 12.2917; 0.0 0.0 … 9.66667 10.0; … ; NaN…
#   "stats" => Dict{String, Any}("wlddim"=>1, "r_prolif_rate"=>1.8, "max_burnin"=…

# %% [markdown]
# It is much faster, although it ignores the biallelic structure, hence there is no dominance coefficient. Instead of *n_loci*, it has *n_segr_regions*; and instead of *n_sel_loci*, it has *prop_of_sel_loci*:

# %%
re_heatmap_pops(test)
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_wN4dEFYTsr.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_wN4dEFYTsr.gif")

# %%
re_heatmap_aasel(test)
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_apgxKTwneR.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_apgxKTwneR.gif")

# %%
re_heatmap_aasel(test;clim=(450,550),slow_factor=0.5)
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_gnaDAtcjSL.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_gnaDAtcjSL.gif")

# %%
re_heatmap_fitn(test;clim=(0.9,1.0))
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_8hSNivEfUX.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_8hSNivEfUX.gif")

# %% [markdown]
# Notice how the fitness distribution gets higher (brighter) overall, after the whole space has been filled and the expansion is essentially stopped.
#
# This can be confirmed with the mean fitness graphs:

# %%
re_heatmap(test,"fitn")
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_STEdkxE52z.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_STEdkxE52z.gif")

# %%
test_fitn_frontarr = front_array(test,"fitn";oneside=true)
re_heatmap(test_fitn_frontarr,2,1,100)
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_or4r4NmbAD.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_or4r4NmbAD.gif")

# %%
test_fitn_frontav = average_front(test,"fitn")
Plots.plot(test_fitn_frontav,xlabel="Generation",label="Mean front fitness")

# %%
test_fitn_av = average_all(test,"fitn")
Plots.plot(test_fitn_av,xlabel="Generation",label="Mean front fitness")

# %% [markdown]
# The front array stays at the end after the space has been filled:
